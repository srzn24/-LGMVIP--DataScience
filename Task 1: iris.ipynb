# %% [markdown]
# # Iris Flowers Classification

# %% [markdown]
# ### Dataset Description
# The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant. One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
# Attribute Information:
#
# 1. sepal length in cm
# 2. sepal width in cm
# 3. petal length in cm
# 4. petal width in cm
# 5. class:
# -- Iris Setosa
# -- Iris Versicolour
# -- Iris Virginica

# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import matplotlib

# %% [markdown]
# #### Importing Dataset

# %%
iris = pd.read_csv('E:\IRIS.csv')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
fig, axarr = plt.subplots(1,2,figsize=(15,8))

iris.dtypes.value_counts().plot.pie(autopct='%1.1f%%',explode=[0.2,0.2],shadow=True,ax=axarr[0])
axarr[0].set_title('percent of data type')

iris.dtypes.value_counts().plot.bar(ax=axarr[1])
axarr[1].set_title('type of data')

plt.show()

# %%
#default theme
sns.set(context='notebook', style='whitegrid', palette='magma', font='verdana', font_scale=1, rc=None)
matplotlib.rcParams['figure.figsize'] =[10,10]
matplotlib.rcParams.update({'font.size': 15})
matplotlib.rcParams['font.family'] = 'sans-serif'
sns.set_style('darkgrid')

# %%
sns.countplot(x='species',data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
iris['species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%'
                                        ,shadow=True, figsize=(10,8))
plt.show()

# %%
iris.plot(kind="scatter", x="sepal_length", y="sepal_width", color="orange")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.FacetGrid(iris, hue="species", size=5) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend()
# Out:
# C:\Users\SUYASH\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# We can look at an individual feature in Seaborn through a boxplot
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
ax = sns.boxplot(x="species", y="petal_length", data=iris)
ax = sns.stripplot(x="species", y="petal_length", data=iris, jitter=True, edgecolor="gray")

# %%
sns.FacetGrid(iris, hue="species", size=6) \
   .map(sns.kdeplot, "petal_length") \
   .add_legend()
# Out:
# C:\Users\SUYASH\anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris.boxplot(by="species", figsize=(12, 6))
# Out:
# array([[<AxesSubplot:title={'center':'petal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'petal_width'}, xlabel='[species]'>],
#        [<AxesSubplot:title={'center':'sepal_length'}, xlabel='[species]'>,
#         <AxesSubplot:title={'center':'sepal_width'}, xlabel='[species]'>]],
#       dtype=object)

# %%
iris.hist(edgecolor='black',figsize=(10,10))
plt.show()

# %%
sns.pairplot(iris , hue='species');

# %%
iris.species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
species = {
    "Species" : {"Iris-setosa":0,"Iris-versicolor":1,"Iris-virginica":2}
}
iris.replace(species,inplace=True)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
iris.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_b686a_row0_col0,#T_b686a_row1_col1,#T_b686a_row2_col2,#T_b686a_row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b686a_row0_col1{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_b686a_row0_col2{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_b686a_row0_col3{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_b686a_row1_col0,#T_b686a_row1_col2,#T_b686a_row1_col3,#T_b686a_row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b686a_row2_col0{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_b686a_row2_col3{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_b686a_row3_col0{
#             background-color:  #e7745b;
#             color:  #000000;
#         }#T_b686a_row3_col1{
# ...

# %%
# SPLIT DATA
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
x = iris.drop('species', axis=1)
y= iris.species
print(x.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=5)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (90, 4)
# (90,)
# (60, 4)
# (60,)

# %% [markdown]
# ### Train and test on the same dataset

# %% [markdown]
# #### knn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
knn.fit(x_train, y_train)

print('The accuracy of the knn classifier is {:.2f} out of 1 on training data'.format(knn.score(x_train, y_train)))
print('The accuracy of the knn classifier is {:.2f} out of 1 on test data'.format(knn.score(x_test, y_test)))
# Out:
# The accuracy of the knn classifier is 0.97 out of 1 on training data
# The accuracy of the knn classifier is 0.97 out of 1 on test data

# %%
k_range = list(range(1,26))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x, y)
    y_pred = knn.predict(x)
    scores.append(metrics.accuracy_score(y, y_pred))
    
plt.plot(k_range, scores)
plt.xlabel('Value of k for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of k of k-Nearest-Neighbors')
plt.show()

# %% [markdown]
# #### logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()
logreg.fit(x, y)
y_pred = logreg.predict(x)
print(metrics.accuracy_score(y, y_pred))
# Out:
# 0.9733333333333334

# %% [markdown]
# #### svm support vector machine

# %%
from sklearn.svm import SVC

# %%
svm = SVC(kernel='rbf', random_state=0, gamma=.10, C=1.0)
svm.fit(x_train, y_train)

print('The accuracy of the svm classifier on training data is {:.2f} out of 1'.format(svm.score(x_train, y_train)))

print('The accuracy of the svm classifier on test data is {:.2f} out of 1'.format(svm.score(x_test, y_test)))
# Out:
# The accuracy of the svm classifier on training data is 0.97 out of 1
# The accuracy of the svm classifier on test data is 0.98 out of 1

# %% [markdown]
# #### naive bayes

# %%
from sklearn.naive_bayes import GaussianNB
nav_byes = GaussianNB()

# model training
nav_byes.fit(x_train, y_train)

# Predicting
Y_Pred_Test_nvb=nav_byes.predict(x_test)

# %%
Y_Pred_Test_nvb
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
# ...

# %%
print("The accuracy of the naive bayes on testing data is",metrics.accuracy_score(y_test, Y_Pred_Test_nvb)*100)
# Out:
# The accuracy of the naive bayes on testing data is 96.66666666666667

# %% [markdown]
# ## Conclusion
# 1. PetalWidthCm was highly correlated with PetalLengthCm and vice versa
# 2. There were no null values in the dataset
# 3. The dataset was distributed equally
# 4. Accuracy score was very high for all the models
